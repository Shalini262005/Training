# %%
df = spark.read.option("header", True).csv("dbfs:/FileStore/tables/ipl_commentary_data.csv")
df.createOrReplaceTempView("commentary_view")

# %%
# %sql
select * from commentary_view limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
